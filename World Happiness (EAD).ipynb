# %% [markdown]
# ## EDA

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('WHR20_DataForTable2.1.xls')

# %%
df.head(5)
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008     3.723590            7.144916        0.450662
# 1  Afghanistan  2009     4.401778            7.314788        0.552308
# 2  Afghanistan  2010     4.758381            7.421525        0.539075
# 3  Afghanistan  2011     3.831719            7.394349        0.521104
# 4  Afghanistan  2012     3.782938            7.480296        0.520637
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                         50.799999                      0.718114    0.178993
# 1                         51.200001                      0.678896    0.201228
# 2                         51.599998                      0.600127    0.131578
# 3                         51.919998                      0.495901    0.173452
# 4                         52.240002                      0.530935    0.246943
#
#    Perceptions of corruption  Positive affect  ...  \
# ...

# %%
df.shape
# Out:
# (1848, 26)

# %%
df.describe()
# Out:
#               year  Life Ladder  Log GDP per capita  Social support  \
# count  1848.000000  1848.000000         1819.000000     1835.000000
# mean   2012.848485     5.445810            9.244531        0.811132
# std       3.962437     1.118989            1.168422        0.118987
# min    2005.000000     2.375092            6.456574        0.290184
# 25%    2010.000000     4.623136            8.309359        0.748296
# 50%    2013.000000     5.363165            9.407829        0.833975
# 75%    2016.000000     6.268130           10.209482        0.904574
# max    2019.000000     8.018934           11.728235        0.987343
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                       1796.000000                   1817.000000
# mean                          63.169525                      0.738467
# std                            7.546524                      0.143059
# min                           32.299999                      0.257534
# ...

# %%
pd.set_option('display.max_rows', 200)
pd.crosstab(index=df['Country name'],columns=df['year'])
# Out:
# year                       2005  2006  2007  2008  2009  2010  2011  2012  \
# Country name
# Afghanistan                   0     0     0     1     1     1     1     1
# Albania                       0     0     1     0     1     1     1     1
# Algeria                       0     0     0     0     0     1     1     1
# Angola                        0     0     0     0     0     0     1     1
# Argentina                     0     1     1     1     1     1     1     1
# Armenia                       0     1     1     1     1     1     1     1
# Australia                     1     0     1     1     0     1     1     1
# Austria                       0     1     0     1     0     1     1     1
# Azerbaijan                    0     1     1     1     1     1     1     1
# Bahrain                       0     0     0     0     1     1     1     1
# Bangladesh                    0     1     1     1     1     1     1     1
# ...

# %% [markdown]
# top 10 countries with the highest average Life Ladder score from year 2005 - 2019

# %%
Ladder_mean_country =df.groupby('Country name')['Life Ladder'].mean().to_frame().reset_index()
Ladder_mean_country = Ladder_mean_country.sort_values(by='Life Ladder',ascending=False)
Ladder_mean_country.head(10)
# Out:
#     Country name  Life Ladder
# 39       Denmark     7.692139
# 47       Finland     7.572871
# 143  Switzerland     7.552649
# 111       Norway     7.537292
# 105  Netherlands     7.463357
# 62       Iceland     7.428166
# 25        Canada     7.401420
# 142       Sweden     7.373469
# 106  New Zealand     7.314375
# 6      Australia     7.293152

# %% [markdown]
# top 10 countries with the lowest average Life Ladder score from year 2005 - 2019

# %%
Ladder_mean_country.tail(10)
# Out:
#                  Country name  Life Ladder
# 31                    Comoros     3.943963
# 165                  Zimbabwe     3.934324
# 163                     Yemen     3.912124
# 147                  Tanzania     3.690970
# 124                    Rwanda     3.654473
# 0                 Afghanistan     3.594628
# 149                      Togo     3.555060
# 22                    Burundi     3.548124
# 26   Central African Republic     3.514954
# 136               South Sudan     3.401875

# %% [markdown]
# Change of average happiness measurements across the world over years 2005 - 2019

# %%
fig, axs = plt.subplots(nrows = 5,ncols=3,figsize=(16,16))

sns.barplot(x="year",y="Life Ladder",data=df,ax=axs[0,0])

sns.barplot(x="year",y="Log GDP per capita",data=df,ax=axs[0,1])

sns.barplot(x="year",y="Social support",data=df,ax=axs[0,2])

sns.barplot(x="year",y="Healthy life expectancy at birth",data=df,ax=axs[1,0])


sns.barplot(x="year",y="Freedom to make life choices",data=df,ax=axs[1,1])


sns.barplot(x="year",y="Generosity",data=df,ax=axs[1,2])

sns.barplot(x="year",y="Perceptions of corruption",data=df,ax=axs[2,0])

sns.barplot(x="year",y="Positive affect",data=df,ax=axs[2,1])

sns.barplot(x="year",y="Negative affect",data=df,ax=axs[2,2])

sns.barplot(x="year",y="Confidence in national government",data=df,ax=axs[3,0])
sns.barplot(x="year",y="Democratic Quality",data=df,ax=axs[3,1])
sns.barplot(x="year",y="Delivery Quality",data=df,ax=axs[3,2])

sns.barplot(x="year",y="GINI index (World Bank estimate)",data=df,ax=axs[4,0])

# %%
corrMatrix = df[df.columns.tolist()[2:14]].corr()

plt.figure(figsize=(10,10))
sns.heatmap(corrMatrix, annot=False)
plt.show()

# %%
for i in range(3,15):
    
    df.plot(x=df.columns.tolist()[i], y='Life Ladder', style='o')  
#plt.title('MinTemp vs MaxTemp')  
#plt.xlabel('MinTemp')  
#plt.ylabel('MaxTemp')  
    plt.show()
